# %% [markdown]
# ## Flujos de Control

# %% [markdown]
# 1) Crear una variable que contenga un elemento del conjunto de números enteros y luego imprimir por pantalla si es mayor o menor a cero

# %% [markdown]
# 2) Crear dos variables y un condicional que informe si son del mismo tipo de dato

# %% [markdown]
# 3) Para los valores enteros del 1 al 20, imprimir por pantalla si es par o impar

# %% [markdown]
# 4) En un ciclo for mostrar para los valores entre 0 y 5 el resultado de elevarlo a la potencia igual a 3

# %% [markdown]
# 5) Crear una variable que contenga un número entero y realizar un ciclo for la misma cantidad de ciclos

# %% [markdown]
# 6) Utilizar un ciclo while para realizar el factorial de un número guardado en una variable, sólo si la variable contiene un número entero mayor a 0

# %% [markdown]
# 7-crear un ciclo for dentro de un ciclo while

# %%
n = 1
while (n < 6):
    print(f'ciclo while n: {n}')
    for i in range(1,6):
        print('ciclo for n=', str(i))
    n+=1
# Out:
# ciclo while n: 1
# ciclo for n= 1
# ciclo for n= 2
# ciclo for n= 3
# ciclo for n= 4
# ciclo for n= 5
# ciclo while n: 2
# ciclo for n= 1
# ciclo for n= 2
# ciclo for n= 3
# ciclo for n= 4
# ciclo for n= 5
# ciclo while n: 3
# ciclo for n= 1
# ciclo for n= 2
# ciclo for n= 3
# ciclo for n= 4
# ciclo for n= 5
# ciclo while n: 4
# ciclo for n= 1
# ciclo for n= 2
# ciclo for n= 3
# ciclo for n= 4
# ciclo for n= 5
# ciclo while n: 5
# ciclo for n= 1
# ciclo for n= 2
# ciclo for n= 3
# ciclo for n= 4
# ciclo for n= 5

# %% [markdown]
# 8 crea un ciclo while dentro de un ciclo for

# %%
n=1
for i in range(n<6):
    print(f'Ciclo For n: {i}')
    while :
        print(f'Ciclo While n= {}')

# %% [markdown]
# 9 Imprimir los numeros primos existentes entre  y 30

# %%
n = 30
while (n >= 30):
    for i in n:
        if i % 2 == 0:
            print("No es primo")
